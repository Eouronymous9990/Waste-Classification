# %%
import os
path =r"C:\Users\zbook 17 g3\Downloads\New folder (6)"

import cvzone
from cvzone.ClassificationModule import Classifier
import cv2

cap = cv2.VideoCapture(0)
classifier = Classifier(r"C:\Users\zbook 17 g3\Downloads\New folder (11)\keras_model.h5", r"C:\Users\zbook 17 g3\Downloads\New folder (11)\labels.txt")
imgArrow = cv2.imread(r"C:\Users\zbook 17 g3\Downloads\New folder (6)\Resources\arrow.png", cv2.IMREAD_UNCHANGED)
classIDBin = 0

imgBinsList = []
pathFolderBins = r"C:\Users\zbook 17 g3\Downloads\New folder (7)\New folder"
pathList = os.listdir(pathFolderBins)
for path in pathList:
    imgBinsList.append(cv2.imread(os.path.join(pathFolderBins, path), cv2.IMREAD_UNCHANGED))



classDic = {0: 1,
            1: 0,
            2: None,

}

while True:
    _, img = cap.read()
    imgResize = cv2.resize(img, (454, 340))

    imgBackground = cv2.imread(r"C:\Users\zbook 17 g3\Downloads\New folder (6)\Resources\background.jpg")

    predection = classifier.getPrediction(img)
    print(predection)


    classID = predection[1]
    print(classID)
    if classID == 1:
        imgBackground = cvzone.overlayPNG(imgBackground, imgArrow, (900, 320))
        
    elif classID == 0:
        imgBackground = cvzone.overlayPNG(imgBackground, imgArrow, (540, 320))


    imgBackground[120:120 + 340, 10:10 + 454] = imgResize
    cv2.imshow("Output", imgBackground)
    cv2.waitKey(1)

#############
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 1s/step
# ([0.00029645636, 0.00092353066, 0.9987801], 2)
# 2
# 1/1 [==============================] - 0s 52ms/step
# ([0.00021144988, 0.0007279776, 0.9990606], 2)
# 2
# 1/1 [==============================] - 0s 46ms/step
# ([0.00014880917, 0.00040094386, 0.99945027], 2)
# 2
# 1/1 [==============================] - 0s 42ms/step
# ([0.00056563626, 0.0008936604, 0.99854076], 2)
# 2
# 1/1 [==============================] - 0s 41ms/step
# ([0.00018835411, 0.00088698376, 0.9989247], 2)
# 2
# 1/1 [==============================] - 0s 39ms/step
# ...
